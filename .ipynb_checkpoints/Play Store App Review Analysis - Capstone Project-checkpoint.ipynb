# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %%
# Importing all the necessary datasets required for data analysis Pandas,numpy,and matplotlib,seaborn for visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import plotly.express as px

# %%
# Importing data set and storing into the variable 
playstore_data=pd.read_csv("Play Store Data.csv")

# %% [markdown]
# # Basic steps
# 1. Head of the dataset
# 2. Dataset shape
# 3. Check data type of every column
# 4. print descriptive summary

# %%
# printing the first 5 rows in the dataset
playstore_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
# Printing the shape of the dataset
playstore_data.shape
# Out:
# (10841, 13)

# %%
# Printing the information of dataset to get the better idea about the datatype and memory used
playstore_data.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 8.3 MB

# %%
# Printing the descriptive statistics
playstore_data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ### Right now when we try to look at the descriptive statistics of the play store data set,
#  - We see only one numerical column from describe function
#
# ## We need to figure out the columns that can be numerical
# ## They are
#  - Rating
#  - Reviews
#  - Size
#  - Installs
#  - Price
#
#
#  ***Out of all the columns only Rating column in numerical***
#
#  So we will start converting all the left out column's data type to numerical (int or float)

# %% [markdown]
# ## 1. Conversion of Column:Reviews from object to float type

# %%
# Printing the data type of Reviews 
playstore_data["Reviews"].dtype
# Out:
# dtype('O')

# %% [markdown]
# - Direct conversion of Reviews column may get some error if column contains any alphabets and special characters
# - So in order to check we can use [isnumeric](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.isnumeric.html) function ***(to check if it contains only digits or not)***  to determine the no of rows having irregular data for conversion

# %%
playstore_data[~ playstore_data["Reviews"].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# The category, Rating and Reviews Column have irregular data so i'am dropping this row having an index 10472
print(playstore_data.shape)
playstore_data.drop(10472,inplace=True)
playstore_data.shape
# Out:
# (10841, 13)
# (10840, 13)

# %%
# Converting the values from object to float
print(playstore_data["Reviews"].dtype)
playstore_data["Reviews"]=playstore_data["Reviews"].astype('int64')
playstore_data["Reviews"].dtype
# Out:
# object
# dtype('int64')

# %% [markdown]
# # 2. Conversion of Column :size from object to float
#  - By looking at the unique data present in the ***size***  column  we have <br>
#       1. Numbers like 8M , 10M etc which denotes that these data have MegaBytes as its unit <br>
#       2. Numbers like 8.5k,23k,1020k etc which denotes that these data have Kilobytes as unit
#
#
#  - So here lets convert all the units to Kilobyte for data analysis

# %%
# Printing the data which have decimal values like 3.1M 2.7M which contains dot ( . )
playstore_data[playstore_data["Size"].str.find(".")!=-1]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10834                                      FR Calculator               FAMILY
# 10835                                           FR Forms             BUSINESS
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
#
#        Rating  Reviews  Size    Installs  Type Price Content Rating  \
# 2         4.7    87510  8.7M  5,000,000+  Free     0       Everyone
# 4         4.3      967  2.8M    100,000+  Free     0       Everyone
# 5         4.4      167  5.6M     50,000+  Free     0       Everyone
# 9         4.7      121  3.1M     10,000+  Free     0       Everyone
# 15        3.2       55  2.7M      5,000+  Free     0       Everyone
# ...       ...      ...   ...         ...   ...   ...            ...
# 10831     NaN       38  9.8M      5,000+  Free     0       Everyone
# 10834     4.0        7  2.6M        500+  Free     0       Everyone
# 10835     NaN        0  9.6M         10+  Free     0       Everyone
# 10837     5.0        4  3.6M        100+  Free     0       Everyone
# 10838     NaN        3  9.5M      1,000+  Free     0       Everyone
#
#                         Genres        Last Updated Current Ver   Android Ver
# 2                 Art & Design      August 1, 2018       1.2.4  4.0.3 and up
# 4      Art & Design;Creativity       June 20, 2018         1.1    4.4 and up
# 5                 Art & Design      March 26, 2017         1.0    2.3 and up
# 9      Art & Design;Creativity        July 3, 2018         2.8  4.0.3 and up
# 15                Art & Design        June 6, 2018         NaN    4.2 and up
# ...                        ...                 ...         ...           ...
# 10831        Maps & Navigation       June 13, 2018   2.0.148.0    4.0 and up
# 10834                Education       June 18, 2017       1.0.0    4.1 and up
# 10835                 Business  September 29, 2016       1.1.5    4.0 and up
# 10837                Education        July 6, 2018         1.0    4.1 and up
# 10838                  Medical    January 20, 2017         1.0    2.2 and up
#
# [3609 rows x 13 columns]

# %%
playstore_data["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '470k',
#        '226k', '240k', '89k', '234k', '257k', '861k', '467k', '157k',
#        '44k', '676k', '67k', '552k', '885k', '1020k', '582k', '619k'],
#       dtype=object)

# %%
# Creating a function to convert the all size to kilobyte units
def convert_to_kilobytes(size):
#     If the data is telling us the size varies with time then lets assign nan values to it
    if size == "Varies with device":
        return np.nan
#     If the data contains M it remmoves M convert it to float and it will be multiplied to float
    elif "M" in size:
        size=size.replace("M","")
        size=float(size)
        return round(size * 1000,2)
#     If the data contains K it remmoves k convert it to float 
    elif "k" in size:
        size=size.replace("k","")
        return round(float(size),2)

# Checking all the usecases of size conversion
convert_to_kilobyrtes('456.6656545465M')\
,convert_to_kilobyrtes('456.34k'),\
convert_to_kilobyrtes('456M'),\
convert_to_kilobyrtes('45.6M')
# Out:
# (456665.65, 456.34, 456000.0, 45600.0)

# %%
values=playstore_data["Size"].apply(convert_to_kilobyrtes)
# checking if all rows are affecting 
values.shape
# Out:
# (10840,)

# %%
playstore_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
# Converting the sizes to kilobyte unit
playstore_data.Size=playstore_data.Size.apply(convert_to_kilobytes)

# %%
playstore_data.Size.dtype
# Out:
# dtype('float64')

# %%
# Checking the head of size conversion
playstore_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size     Installs  Type Price Content Rating  \
# 0      159  19000.0      10,000+  Free     0       Everyone
# 1      967  14000.0     500,000+  Free     0       Everyone
# 2    87510   8700.0   5,000,000+  Free     0       Everyone
# 3   215644  25000.0  50,000,000+  Free     0           Teen
# 4      967   2800.0     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# # 3. Conversion of Column : Installs to integer
#
#  - The data contains string like '+' and ',' need to remove that and convert it into int type

# %%
# So here we have + and , to be removed in order to convert into into integer data type
playstore_data.Installs.unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
# regex logic used 
pattern=r'[+,]'
# use cases of Removing + and , from stirng
re.sub(pattern,'',"10,000+"),re.sub(pattern,'',"10,00,000+")
# Out:
# ('10000', '1000000')

# %%
# Replacing the + and , from string
pattern=r'[+,]'
playstore_data.Installs=playstore_data.Installs.apply(lambda x: re.sub(pattern,'',x) )

# %%
# Checking if all the unique numbers are appropraite to convert it into int 
playstore_data.Installs.unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
# Conversion from Object to integer data type
playstore_data.Installs=playstore_data.Installs.astype("int64")
playstore_data.Installs.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # 4. Conversion of column :Price from Object to float
#  - It contains only dollar symbol ***'$'***
#
#  - Remove  the ***$*** symbol
#  - Convert the type to float

# %%
# There are 92 unique values
playstore_data.Price.unique(),playstore_data.Price.unique().shape
# Out:
# (array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#         '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#         '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#         '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#         '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#         '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#         '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#         '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#         '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#         '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#         '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#         '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#         '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#         '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object),
#  (92,))

# %%
playstore_data.Price=playstore_data.Price.str.replace("$","")
# Out:
# <ipython-input-1414-ecb171b1b735>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   playstore_data.Price=playstore_data.Price.str.replace("$","")

# %%
# Checkiing if all the data is appropriate to convert to flaot
playstore_data.Price.unique(),playstore_data.Price.unique().shape
# Out:
# (array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#         '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#         '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#         '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#         '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#         '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#         '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#         '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#         '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#         '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#         '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#         '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#         '1.20', '1.04'], dtype=object),
#  (92,))

# %%
playstore_data.Price=playstore_data.Price.astype('float')
playstore_data.Price.dtype
# Out:
# dtype('float64')

# %%
playstore_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
# Lasted updated column in object form lets convert it into date date type
playstore_data["Last Updated"]=pd.to_datetime(playstore_data["Last Updated"])
# =playstore_data["Last Updated"]

# %%
# Adding Year Month Date columns
playstore_data["Year"]=playstore_data["Last Updated"].dt.year
playstore_data["Month"]=playstore_data["Last Updated"].dt.month
playstore_data["Date"]=playstore_data["Last Updated"].dt.day

# %%
playstore_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Year            10840 non-null  int64
#  14  Month           10840 non-null  int64
#  15  Date            10840 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(7)
# memory usage: 1.4+ MB

# %%
playstore_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up
#
#    Year  Month  Date
# 0  2018      1     7
# 1  2018      1    15
# 2  2018      8     1
# 3  2018      6     8
# 4  2018      6    20

# %% [markdown]
# # Data cleaning

# %%
# Presenting the errors of the dataset in dataframe format
null_value_tables=pd.DataFrame({"No of Null values":playstore_data.isna().sum().sort_values(ascending=False),
                               "% of null vales":(playstore_data.isna().sum().sort_values(ascending=False)
                                                  /playstore_data.shape[0])*100})

# %%
null_value_tables
# Out:
#                 No of Null values  % of null vales
# Size                         1695        15.636531
# Rating                       1474        13.597786
# Current Ver                     8         0.073801
# Android Ver                     2         0.018450
# Type                            1         0.009225
# App                             0         0.000000
# Category                        0         0.000000
# Reviews                         0         0.000000
# Installs                        0         0.000000
# Price                           0         0.000000
# Content Rating                  0         0.000000
# Genres                          0         0.000000
# Last Updated                    0         0.000000
# Year                            0         0.000000
# Month                           0         0.000000
# Date                            0         0.000000

# %% [markdown]
# # 1. 15% of Size column are errors
# ## 2. 13% of Rating columns are errors
# ### 3. Current Version with 8 errors
# ####  4.Andriod version with 2 and
# ###### 5. Type with 1 error

# %% [markdown]
# # Handling missing values for Size
#  Adding overall mean values to the Size column might not feel appropriate as becasue usually
#   - Apps with category like Games will have more size and
#   - Apps with category of health will have slightly lesser size compared to games
#
#   By looking at the table below we can tell that ***GAME*** has average maximum value followed by ***FAMILY*** and ***TRAVEL_AND_LOCAL*** and ***SPORTS*** and so on ...
#
#  Conclusion - Group the apps by category and fill the mean values for missing places of there corresponding category

# %%
# Storing the mean values of all the category
category_mean=playstore_data.groupby("Category").mean().sort_values("Size",ascending=False)["Size"]
# Printing the categories with there over all average
category_mean
# Out:
# Category
# GAME                   44370.098522
# FAMILY                 28319.250546
# TRAVEL_AND_LOCAL       24654.494792
# SPORTS                 24339.012862
# HEALTH_AND_FITNESS     22769.212121
# PARENTING              22512.962963
# FOOD_AND_DRINK         22185.000000
# ENTERTAINMENT          21853.333333
# EDUCATION              20790.828829
# AUTO_AND_VEHICLES      20037.146667
# MEDICAL                19629.039171
# FINANCE                17928.566775
# SOCIAL                 17681.871429
# PHOTOGRAPHY            17367.665354
# DATING                 16625.556604
# MAPS_AND_NAVIGATION    16614.712963
# SHOPPING               16175.427861
# VIDEO_PLAYERS          16084.580153
# HOUSE_AND_HOME         15978.764706
# LIFESTYLE              14754.498551
# BUSINESS               14472.162500
# EVENTS                 13963.754386
# BEAUTY                 13795.744681
# COMICS                 13485.352941
# BOOKS_AND_REFERENCE    13310.822335
# WEATHER                13124.245614
# NEWS_AND_MAGAZINES     13023.648148
# PRODUCTIVITY           12981.415842
# ART_AND_DESIGN         12370.967742
# COMMUNICATION          11766.705660
# PERSONALIZATION        11298.149296
# LIBRARIES_AND_DEMO     11083.335366
# TOOLS                   8771.250338
# Name: Size, dtype: float64

# %%
category_mean["GAME"]
# Out:
# 44370.098522167485

# %%
# Storing the null values with mean of the category
playstore_data.loc[playstore_data["Size"].isna(),["Size"]]=\
playstore_data.loc[playstore_data.Size.isna()].apply(lambda x :round(category_mean[x['Category']],2),axis=1)

# %%
# Presenting the errors of the dataset in dataframe format
null_value_tables=pd.DataFrame({"No of Null values":playstore_data.isna().sum().sort_values(ascending=False),
                               "% of null vales":(playstore_data.isna().sum().sort_values(ascending=False)
                                                  /playstore_data.shape[0])*100}) 
null_value_tables
# Out:
#                 No of Null values  % of null vales
# Rating                       1474        13.597786
# Current Ver                     8         0.073801
# Android Ver                     2         0.018450
# Type                            1         0.009225
# App                             0         0.000000
# Category                        0         0.000000
# Reviews                         0         0.000000
# Size                            0         0.000000
# Installs                        0         0.000000
# Price                           0         0.000000
# Content Rating                  0         0.000000
# Genres                          0         0.000000
# Last Updated                    0         0.000000
# Year                            0         0.000000
# Month                           0         0.000000
# Date                            0         0.000000

# %% [markdown]
# # Handling missing values of Column: Rating
#  - Rating can be very random depending upon the customer satisfaction

# %%
# This function assign_random_values will assign random values picked from non null values to the missing values (null val)

# Steps taken in this function 
#  Step 1 - n - get the length of sample you want by getting the length of null values in the feature
#  Step 2 - remove the null values from the feature
#  Step 3 -pick -n - number of sample required from null filter feature
#  Step 4 -  get the index of null values from feature
#  Step 5 - assign null values indices to picked sample indices
#  Step 6 - Add that to the main dataset

def assign_random_values(feature):
    sample_length=  playstore_data[feature].isna().sum()
    sample_rating_value=playstore_data[~playstore_data[feature].isna()][feature].sample(sample_length)
    actual_null_list=playstore_data[playstore_data[feature].isna()]
    sample_rating_value.index=actual_null_list.index
    playstore_data.loc[playstore_data[feature].isna(),feature]=sample_rating_value

# %%
# Replaced the missing values with sample picked values 
assign_random_values("Rating")

# %%
playstore_data.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# Year              0
# Month             0
# Date              0
# dtype: int64

# %% [markdown]
# ## Left out columns having missing values are Andriod ver, Current ver and Type
#  - The number of errors are negligible ***(less than 10)*** comapared to the length of overall dataset we can follow the same method used for filling missing values of Rating

# %%
assign_random_values("Android Ver")
assign_random_values("Current Ver")
assign_random_values("Type")

# %%
playstore_data.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# Year              0
# Month             0
# Date              0
# dtype: int64

# %% [markdown]
# ### So finally we have cleaned all the missing value from Ratings,Size,Andriod Ver,Current ver,Type

# %%
# Presenting the errors of the dataset in dataframe format
null_value_tables=pd.DataFrame({"No of Null values":playstore_data.isna().sum().sort_values(ascending=False),
                               "% of null vales":(playstore_data.isna().sum().sort_values(ascending=False)
                                                  /playstore_data.shape[0])*100}) 
null_value_tables
# Out:
#                 No of Null values  % of null vales
# App                             0              0.0
# Category                        0              0.0
# Rating                          0              0.0
# Reviews                         0              0.0
# Size                            0              0.0
# Installs                        0              0.0
# Type                            0              0.0
# Price                           0              0.0
# Content Rating                  0              0.0
# Genres                          0              0.0
# Last Updated                    0              0.0
# Current Ver                     0              0.0
# Android Ver                     0              0.0
# Year                            0              0.0
# Month                           0              0.0
# Date                            0              0.0

# %% [markdown]
# # Removing duplicate values

# %%
# Printing the duplicate values from dataset
playstore_data[playstore_data.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
#        Reviews      Size   Installs  Type  Price Content Rating        Genres  \
# 229      80805  14472.16    5000000  Free    0.0       Everyone      Business
# 236     159872  14472.16   10000000  Free    0.0       Everyone      Business
# 239      70991  14472.16    5000000  Free    0.0       Everyone      Business
# 256      31614  37000.00   10000000  Free    0.0       Everyone      Business
# 261       6989  14472.16    1000000  Free    0.0       Everyone      Business
# ...        ...       ...        ...   ...    ...            ...           ...
# 8643    404610  12981.42   10000000  Free    0.0       Everyone  Productivity
# 8654     25370  12981.42    1000000  Free    0.0       Everyone  Productivity
# 8658   2401017  12981.42  100000000  Free    0.0       Everyone  Productivity
# 10049      123  86000.00      10000  Free    0.0       Everyone       Medical
# 10768       63  24000.00      10000  Free    0.0       Everyone       Medical
#
#       Last Updated         Current Ver         Android Ver  Year  Month  Date
# 229     2018-02-26  Varies with device        4.0.3 and up  2018      2    26
# 236     2018-07-31  Varies with device  Varies with device  2018      7    31
# 239     2018-07-24    2.19.0.204537701          4.4 and up  2018      7    24
# 256     2018-07-20      4.1.28165.0716          4.0 and up  2018      7    20
# 261     2018-07-16           4.3.0.508          4.4 and up  2018      7    16
# ...            ...                 ...                 ...   ...    ...   ...
# 8643    2018-04-06  Varies with device  Varies with device  2018      4     6
# 8654    2018-08-06  Varies with device  Varies with device  2018      8     6
# 8658    2018-06-27  Varies with device  Varies with device  2018      6    27
# 10049   2018-06-01              0.6.88          5.0 and up  2018      6     1
# 10768   2018-06-22               2.3.1          5.0 and up  2018      6    22
#
# [474 rows x 16 columns]

# %%
# Removing duplicates from playstore dataset
playstore_data.drop_duplicates(inplace=True)

# %%
playstore_data[playstore_data["App"]=="Slack"]
# Out:
#        App  Category  Rating  Reviews      Size  Installs  Type  Price  \
# 240  Slack  BUSINESS     4.4    51507  14472.16   5000000  Free    0.0
# 294  Slack  BUSINESS     4.4    51510  14472.16   5000000  Free    0.0
#
#     Content Rating    Genres Last Updated         Current Ver  \
# 240       Everyone  Business   2018-08-02  Varies with device
# 294       Everyone  Business   2018-08-02  Varies with device
#
#             Android Ver  Year  Month  Date
# 240  Varies with device  2018      8     2
# 294  Varies with device  2018      8     2

# %% [markdown]
#  - There are two slack apps rows in the dataset similarly we have Minecraft game also

# %%
playstore_data[playstore_data["App"].duplicated()]
# Out:
#                                             App       Category  Rating  \
# 285                Quick PDF Scanner + OCR FREE       BUSINESS     4.2
# 293      OfficeSuite : Free Office + PDF Editor       BUSINESS     4.3
# 294                                       Slack       BUSINESS     4.4
# 382    Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 383               imo free video calls and chat  COMMUNICATION     4.3
# ...                                         ...            ...     ...
# 10647                         Motorola FM Radio  VIDEO_PLAYERS     3.9
# 10715                        FarmersOnly Dating         DATING     3.0
# 10720        Firefox Focus: The privacy browser  COMMUNICATION     4.4
# 10730                               FP Notebook        MEDICAL     4.5
# 10753            Slickdeals: Coupons & Shopping       SHOPPING     4.5
#
#         Reviews      Size    Installs  Type  Price Content Rating  \
# 285       80804  14472.16     5000000  Free    0.0       Everyone
# 293     1002859  35000.00   100000000  Free    0.0       Everyone
# 294       51510  14472.16     5000000  Free    0.0       Everyone
# 382    56646578  11766.71  1000000000  Free    0.0       Everyone
# 383     4785988  11000.00   500000000  Free    0.0       Everyone
# ...         ...       ...         ...   ...    ...            ...
# 10647     54815  16084.58   100000000  Free    0.0       Everyone
# 10715      1145   1400.00      100000  Free    0.0     Mature 17+
# 10720     36981   4000.00     1000000  Free    0.0       Everyone
# 10730       410  60000.00       50000  Free    0.0       Everyone
# 10753     33599  12000.00     1000000  Free    0.0       Everyone
#
#                         Genres Last Updated         Current Ver  \
# 285                   Business   2018-02-26  Varies with device
# 293                   Business   2018-08-02           9.7.14188
# 294                   Business   2018-08-02  Varies with device
# 382              Communication   2018-08-01  Varies with device
# 383              Communication   2018-06-08    9.8.000000010501
# ...                        ...          ...                 ...
# 10647  Video Players & Editors   2018-05-02  Varies with device
# 10715                   Dating   2016-02-25                 2.2
# 10720            Communication   2018-07-06                 5.2
# 10730                  Medical   2018-03-24           2.1.0.372
# 10753                 Shopping   2018-07-30                 3.9
#
#               Android Ver  Year  Month  Date
# 285          4.0.3 and up  2018      2    26
# 293            4.1 and up  2018      8     2
# 294    Varies with device  2018      8     2
# 382    Varies with device  2018      8     1
# 383            4.0 and up  2018      6     8
# ...                   ...   ...    ...   ...
# 10647  Varies with device  2018      5     2
# 10715          4.0 and up  2016      2    25
# 10720          5.0 and up  2018      7     6
# 10730          4.4 and up  2018      3    24
# 10753          4.4 and up  2018      7    30
#
# [707 rows x 16 columns]

# %% [markdown]
#  - There are around 706 Apps duplicates

# %%
playstore_data=playstore_data[~playstore_data["App"].duplicated()]

# %%
# printing the final length of the dataset after removing the duplicates
playstore_data.shape
# Out:
# (9659, 16)

# %%
# Came through this problems while checking the scenario if Price for all paid type are greater than 0
# Problems I found here are
#  1. Type is Paid But the Price is zero and
#  2. Installs is Zero But we have 5 Ratings
# Conclusion here the data is inappropriate which might cause some confusion when compared to others
playstore_data[playstore_data["Type"]=="Paid"].sort_values("Price").head(2)
# Out:
#                  App Category  Rating  Reviews     Size  Installs  Type  \
# 7107  CB Frequencies    TOOLS     4.0        5   1400.0       100  Paid
# 5846       YAKALA AY     GAME     4.2        0  14000.0         1  Paid
#
#       Price Content Rating  Genres Last Updated Current Ver   Android Ver  \
# 7107   0.99       Everyone   Tools   2015-12-24         1.0  4.0.3 and up
# 5846   0.99       Everyone  Arcade   2018-07-07         1.0    4.1 and up
#
#       Year  Month  Date
# 7107  2015     12    24
# 5846  2018      7     7

# %%
playstore_data.shape
# Out:
# (9659, 16)

# %%
# Removing that row using index "9148"
playstore_data.drop(9148,inplace=True)
playstore_data.shape
# Out:
# (9658, 16)

# %% [markdown]
# ## End of data cleaning

# %% [markdown]
# # Now the data is cleaned and the dataset is ready to export
#  - For further Data Visualization with tools Tableau

# %%
# Exporting the dataset for visualization by other tool
playstore_data.to_csv("cleaned_play_store.csv")

# %% [markdown]
# # Now divide the dataset into 2 parts
#  - Categorical columns
#  - Numerical columns
#
# #### Note - We can easily differentiate the dataset between categorial and numerical i.e
# ##### - group the columns with object type as categorical
# ##### - group the columns without object type as numerical

# %%
# Listing out all the numerical columns
numerical_column=[x for x in playstore_data.columns if playstore_data[x].dtype !="O"]
numerical_column
# Out:
# ['Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Price',
#  'Last Updated',
#  'Year',
#  'Month',
#  'Date']

# %%
# Listing out all the categorical columns

catogorical_columns=[x for x in playstore_data.columns if playstore_data[x].dtype=="O"]
catogorical_columns
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
# Storing all columns of numerical data
numerical_data=playstore_data[numerical_column]
numerical_data
# Out:
#        Rating  Reviews      Size  Installs  Price Last Updated  Year  Month  \
# 0         4.1      159  19000.00     10000    0.0   2018-01-07  2018      1
# 1         3.9      967  14000.00    500000    0.0   2018-01-15  2018      1
# 2         4.7    87510   8700.00   5000000    0.0   2018-08-01  2018      8
# 3         4.5   215644  25000.00  50000000    0.0   2018-06-08  2018      6
# 4         4.3      967   2800.00    100000    0.0   2018-06-20  2018      6
# ...       ...      ...       ...       ...    ...          ...   ...    ...
# 10836     4.5       38  53000.00      5000    0.0   2017-07-25  2017      7
# 10837     5.0        4   3600.00       100    0.0   2018-07-06  2018      7
# 10838     4.4        3   9500.00      1000    0.0   2017-01-20  2017      1
# 10839     4.5      114  13310.82      1000    0.0   2015-01-19  2015      1
# 10840     4.5   398307  19000.00  10000000    0.0   2018-07-25  2018      7
#
#        Date
# 0         7
# 1        15
# 2         1
# 3         8
# 4        20
# ...     ...
# 10836    25
# 10837     6
# 10838    20
# 10839    19
# 10840    25
#
# [9658 rows x 9 columns]

# %%
# Storing all columns of categorical data

catogorical_data=playstore_data[catogorical_columns]
catogorical_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Type Content Rating                     Genres         Current Ver  \
# 0      Free       Everyone               Art & Design               1.0.0
# 1      Free       Everyone  Art & Design;Pretend Play               2.0.0
# 2      Free       Everyone               Art & Design               1.2.4
# 3      Free           Teen               Art & Design  Varies with device
# 4      Free       Everyone    Art & Design;Creativity                 1.1
# ...     ...            ...                        ...                 ...
# 10836  Free       Everyone                  Education                1.48
# 10837  Free       Everyone                  Education                 1.0
# 10838  Free       Everyone                    Medical                 1.0
# 10839  Free     Mature 17+          Books & Reference  Varies with device
# 10840  Free       Everyone                  Lifestyle  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [9658 rows x 7 columns]

# %% [markdown]
# # Loading the second dataset User Reviews

# %%
# Importing the second dataset
user_reviews=pd.read_csv("User Reviews.csv")

# %% [markdown]
# # Basic steps
# 1. Head of the dataset
# 2. Dataset shape
# 3. Check data type of every column
# 4. print descriptive summary

# %%
user_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
user_reviews.shape
# Out:
# (64295, 5)

# %%
user_reviews.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 16.3 MB

# %%
user_reviews.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# # Data cleaning

# %%
user_reviews.isna().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# There are around 26863 rows having null values in all 4 columns
# Translated_Review,Sentiment,Sentiment_Polarity,Sentiment_Subjectivity,

user_reviews.dropna(subset=['Translated_Review',"Sentiment","Sentiment_Polarity","Sentiment_Subjectivity"], how='all',
                    inplace=True)

# %%
user_reviews.isna().sum()
# Out:
# App                       0
# Translated_Review         5
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
user_reviews.shape
# Out:
# (37432, 5)

# %% [markdown]
# ### There are 5 null values present in the Translated Review column
# #### -  Here we have COLUMNS of Sentiment_polarity and Sentiment_subjectivity with values as 0 which is totally not making any difference with the Sentiment as Neutral will de droping this

# %%
# Droping the 5 rows which has nan values in Translated _review
user_reviews[user_reviews["Translated_Review"].isna()]
# Out:
#                                              App Translated_Review Sentiment  \
# 268                                         11st               NaN   Neutral
# 15048        Birds Sounds Ringtones & Wallpapers               NaN   Neutral
# 22092             Calorie Counter - MyFitnessPal               NaN   Neutral
# 31623                                  DC Comics               NaN   Neutral
# 52500  Garden Photo Frames - Garden Photo Editor               NaN   Neutral
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 268                   0.0                     0.0
# 15048                 0.0                     0.0
# 22092                 0.0                     0.0
# 31623                 0.0                     0.0
# 52500                 0.0                     0.0

# %%
# Dropping 5 rows from Translaetd Review which are nan
user_reviews.dropna(subset=["Translated_Review"] ,inplace=True)

# %%
user_reviews.shape
# Out:
# (37427, 5)

# %%
user_reviews.isna().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %% [markdown]
# ### End Of Data Cleaning

# %% [markdown]
# ### There is no need of removing duplicate values because multiple customers can give similar type of reviews

# %%
# Export dataset which has under gone data cleaning
user_reviews.to_csv('clean_user_reviews.csv')

# %% [markdown]
# # Handling Outliers and Visualizing  First data set Play Store Data

# %%
numerical_data[["Rating","Reviews","Size","Installs"]].describe()
# Out:
#             Rating       Reviews           Size      Installs
# count  9658.000000  9.658000e+03    9658.000000  9.658000e+03
# mean      4.176714  2.166150e+05   20248.658076  7.778312e+06
# std       0.534545  1.831413e+06   20635.939283  5.376100e+07
# min       1.000000  0.000000e+00       8.500000  0.000000e+00
# 25%       4.000000  2.500000e+01    5300.000000  1.000000e+03
# 50%       4.300000  9.670000e+02   13217.535000  1.000000e+05
# 75%       4.500000  2.940800e+04   27000.000000  1.000000e+06
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09

# %%
# find lower upper limit using IQR formula to filter outlier

def get_lower_upper_limit(dataframe,feature):
    '''
    dataframe = It refers to the dataset u use 
    
    feature = It refers to the column or feature which lower limit 
    and upper limit has to be found out
    
    Returns-
    This funtion returns the lower limit and upper limit respectively 
    it takes dataframe and column name as arguments
    
    '''
    quartile_1=dataframe[feature].quantile(.25)
    quartile_3=dataframe[feature].quantile(.75)
    interquantile_range=quartile_3-quartile_1
    uplimit=quartile_3 +(1.5 * interquantile_range)
    downlimit=quartile_1 -(1.5 * interquantile_range)
    return downlimit,uplimit

# %%
# This function is used to set the nearest limit to the outliers
def replace_outliers_to_nearest_limit(dataframe,feature,set_down_limit=False,down_limit=0,set_up_limit=False,up_limit=0):
    '''
    dataframe = It refers to the dataset u use 
    
    feature = It refers to the column or feature which lower limit 
    and upper limit has to be found out
    
    set_down_limit (default)= False
    If set_down_limit=True it ignores the lower limit 
    and sets the custom lower limit given by uesr input
    
    down_limit (default)=0
    It assigns the down_limit value to lower limit when the argument 'set_down_limit' is True
    
    set_up_limit (default)= False
    If set_up_limit=True it ignores the upper limit 
    and sets the custom upper limit given by uesr input
    
    up_limit (default)=0
    It assigns the up_limit value to upper limit when the argument 'set_up_limit' is True
    
    '''
    downlimit,uplimit=get_lower_upper_limit(dataframe,feature)
    print(downlimit,uplimit)
    if set_down_limit: downlimit=down_limit;
    if set_up_limit: uplimit=up_limit;
    dataframe.loc[dataframe[feature] < downlimit,feature]=downlimit
    dataframe.loc[dataframe[feature] > uplimit,feature]=uplimit

# %%
numerical_data.describe()
# Out:
#             Rating       Reviews           Size      Installs        Price  \
# count  9658.000000  9.658000e+03    9658.000000  9.658000e+03  9658.000000
# mean      4.176714  2.166150e+05   20248.658076  7.778312e+06     1.099413
# std       0.534545  1.831413e+06   20635.939283  5.376100e+07    16.853021
# min       1.000000  0.000000e+00       8.500000  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01    5300.000000  1.000000e+03     0.000000
# 50%       4.300000  9.670000e+02   13217.535000  1.000000e+05     0.000000
# 75%       4.500000  2.940800e+04   27000.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09   400.000000
#
#              Year        Month         Date
# count  9658.00000  9658.000000  9658.000000
# mean   2017.34562     6.364051    15.631704
# std       1.13764     2.659746     9.430666
# min    2010.00000     1.000000     1.000000
# 25%    2017.00000     5.000000     7.000000
# 50%    2018.00000     7.000000    16.000000
# 75%    2018.00000     8.000000    24.000000
# max    2018.00000    12.000000    31.000000

# %% [markdown]
# # Handling Size outliers

# %%
get_lower_upper_limit(playstore_data,"Size")
# Out:
# (-27250.0, 59550.0)

# %% [markdown]
# #### Note - Need to ignore the minus sign in the lower limit because size cant be negative or even zero MB
#  - The uplimit and downlimit are ***(smallest memory size) 8.5kb*** and 61MB for the over all apps
#  - Box plot for the over all size will look something like the section below

# %%
sns.boxplot(playstore_data.Size)
# Out:
# C:\Users\Melon\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Size'>

# %%
playstore_data.Size.describe()
# Out:
# count      9658.000000
# mean      20248.658076
# std       20635.939283
# min           8.500000
# 25%        5300.000000
# 50%       13217.535000
# 75%       27000.000000
# max      100000.000000
# Name: Size, dtype: float64

# %%
# The outliers has been reset to the nearest limits
replace_outliers_to_nearest_limit(playstore_data,"Size",set_down_limit=True,down_limit=8.5)
# Out:
# -27250.0 59550.0

# %% [markdown]
# NOTE - downlimit is -27MB size can be negative or zero
# - In the Size columns the uplimit and downlimit are between 8.5kb to 61MB <br>
#  Why 8.5 kb ?? - Because its the smallest memory size nearest to 0
# - Now in the box plot in the cell below we dont see any outliers

# %%
sns.boxplot(playstore_data.Size)
# Out:
# C:\Users\Melon\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Size'>

# %% [markdown]
# # Handling Rating outliers

# %%
get_lower_upper_limit(playstore_data,"Rating")
# Out:
# (3.25, 5.25)

# %% [markdown]
# #### Note - Need to ignore the values more than 5 in the upper limit because max rating that a customer can give is 5
#  - The uplimit and downlimit of ratings are 3.25 to 5
#  - Box plot for the over all Rating will look something like the section below

# %%
sns.boxplot(playstore_data.Rating)
# Out:
# C:\Users\Melon\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating'>

# %%
# The outliers has been reset to the nearest limits
replace_outliers_to_nearest_limit(playstore_data,"Rating",set_up_limit=True,up_limit=5)
# Out:
# 3.25 5.25

# %% [markdown]
# #### Note - Need to ignore the values more than 5 in the upper limit because max rating that a customer can give is 5
# - In the Rating columns the uplimit and downlimit are between 3.25 to 5 <br>
# - Now in the box plot in the cell below we dont see any outliers

# %%
sns.boxplot(playstore_data.Rating)
# Out:
# C:\Users\Melon\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating'>

# %% [markdown]
# # Handling Reviews outliers

# %%
get_lower_upper_limit(playstore_data,"Reviews")
# Out:
# (-44049.5, 73482.5)

# %% [markdown]
# #### Note - Need to ignore the negative value in the lower limit because min Reviews that an app can get is 0
#  - The uplimit and downlimit of ratings are 0 and 115844
#  - Box plot for the over all Review will look something like the section below

# %%
sns.boxplot(playstore_data.Reviews)
# Out:
# C:\Users\Melon\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Reviews'>

# %%
# The outliers has been reset to the nearest limits
replace_outliers_to_nearest_limit(playstore_data,"Reviews",set_down_limit=True,down_limit=0)
# Out:
# -44049.5 73482.5

# %% [markdown]
# #### Note - Need to ignore the negative value in the lower limit because min Reviews that an app can get is 0
#  - The uplimit and downlimit of ratings are 0 and 115844
#  - Now in the box plot in the cell below we dont see any outliers

# %%
sns.boxplot(playstore_data.Reviews)
# Out:
# C:\Users\Melon\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Reviews'>

# %% [markdown]
# # Handling Price outliers
#  - While handling price outliers we need to filter the data from app having type as ***Paid*** and finding its outlier

# %%
paid_apps=playstore_data[playstore_data["Type"]=="Paid"]

# %%
paid_apps.shape
# Out:
# (756, 16)

# %%
paid_apps.head()
# Out:
#                                                App       Category  Rating  \
# 234  TurboScan: scan documents and receipts in PDF       BUSINESS    4.70
# 235                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS    4.80
# 427                             Puffin Browser Pro  COMMUNICATION    4.00
# 476                      Moco+ - Chat, Meet People         DATING    4.20
# 477                                     Calculator         DATING    3.25
#
#      Reviews      Size  Installs  Type  Price Content Rating         Genres  \
# 234  11442.0   6800.00    100000  Paid   4.99       Everyone       Business
# 235  10295.0  39000.00    100000  Paid   4.99       Everyone       Business
# 427  18247.0  11766.71    100000  Paid   3.99       Everyone  Communication
# 476   1545.0  16625.56     10000  Paid   3.99     Mature 17+         Dating
# 477     57.0   6200.00      1000  Paid   6.99       Everyone         Dating
#
#     Last Updated  Current Ver Android Ver  Year  Month  Date
# 234   2018-03-25        1.5.2  4.0 and up  2018      3    25
# 235   2017-04-11        3.4.6  3.0 and up  2017      4    11
# 427   2018-07-05  7.5.3.20547  4.1 and up  2018      7     5
# 476   2018-06-19      2.6.139  4.1 and up  2018      6    19
# 477   2017-10-25        1.1.6  4.0 and up  2017     10    25

# %%
paid_apps.Price.describe()
# Out:
# count    756.000000
# mean      14.045146
# std       58.743615
# min        0.990000
# 25%        1.490000
# 50%        2.990000
# 75%        4.990000
# max      400.000000
# Name: Price, dtype: float64

# %%
paid_apps[paid_apps["Price"]!=0].sort_values("Price")
# Out:
#                                  App   Category  Rating  Reviews     Size  \
# 7107                  CB Frequencies      TOOLS     4.0      5.0   1400.0
# 5846                       YAKALA AY       GAME     4.2      0.0  14000.0
# 5961           Ice Crush 10.000 B.C.     FAMILY     4.4     31.0   4200.0
# 6088  Wolf of the BF:Commando MOBILE       GAME     3.4     32.0  27000.0
# 7730                          UFO-CQ      TOOLS     4.3      1.0    237.0
# ...                              ...        ...     ...      ...      ...
# 5354                  I am Rich Plus     FAMILY     4.0    856.0   8700.0
# 4362                      💎 I'm rich  LIFESTYLE     3.8    718.0  26000.0
# 5369                       I am Rich    FINANCE     4.3    180.0   3800.0
# 5362                   I Am Rich Pro     FAMILY     4.4    201.0   2700.0
# 4367        I'm Rich - Trump Edition  LIFESTYLE     3.6    275.0   7300.0
#
#       Installs  Type   Price Content Rating         Genres Last Updated  \
# 7107       100  Paid    0.99       Everyone          Tools   2015-12-24
# 5846         1  Paid    0.99       Everyone         Arcade   2018-07-07
# 5961       100  Paid    0.99       Everyone         Casual   2013-08-15
# 6088      1000  Paid    0.99   Everyone 10+         Arcade   2017-03-23
# 7730        10  Paid    0.99       Everyone          Tools   2016-07-04
# ...        ...   ...     ...            ...            ...          ...
# 5354     10000  Paid  399.99       Everyone  Entertainment   2018-05-19
# 4362     10000  Paid  399.99       Everyone      Lifestyle   2018-03-11
# 5369      5000  Paid  399.99       Everyone        Finance   2018-03-22
# 5362      5000  Paid  399.99       Everyone  Entertainment   2017-05-30
# 4367     10000  Paid  400.00       Everyone      Lifestyle   2018-05-03
#
#      Current Ver   Android Ver  Year  Month  Date
# 7107         1.0  4.0.3 and up  2015     12    24
# 5846         1.0    4.1 and up  2018      7     7
# 5961        1.48    2.0 and up  2013      8    15
# 6088     1.00.10    4.0 and up  2017      3    23
# 7730           1    2.0 and up  2016      7     4
# ...          ...           ...   ...    ...   ...
# 5354         3.0    4.4 and up  2018      5    19
# 4362       1.0.0    4.4 and up  2018      3    11
# 5369         1.0    4.2 and up  2018      3    22
# 5362        1.54    1.6 and up  2017      5    30
# 4367       1.0.1    4.1 and up  2018      5     3
#
# [756 rows x 16 columns]

# %%
get_lower_upper_limit(paid_apps,"Price")
# Out:
# (-3.76, 10.24)

# %% [markdown]
# #### Note - Need to ignore the negative value in the lower limit because min Price can't less than 0 dollars
#  - The uplimit and downlimit of ratings are 0 and 10.24
#  - Box plot for the over all Review will look something like the section below

# %%
sns.boxplot(paid_apps.Price)
# Out:
# C:\Users\Melon\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Price'>

# %%
# The outliers has been reset to the nearest limits
replace_outliers_to_nearest_limit(paid_apps,"Price",set_down_limit=True,down_limit=.99)
# Out:
# -3.76 10.24
# C:\Users\Melon\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Melon\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# #### Note - Need to ignore the negative value in the lower limit because min Price can't less than 0 dollars
#  - The uplimit and downlimit of ratings are .99 and 10.24 <br>
#  WHY?? .99 Becasue it nearest values to the lowwe limit and paid apps cant be 0 dollars
#
#  - Now in the box plot in the cell below we dont see any outliers

# %%
sns.boxplot(paid_apps.Price)
# Out:
# C:\Users\Melon\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %% [markdown]
# # EDA
# Now lets explore
#  - insights of data
#  - get some data patterns,trends

# %%
# Correlation between the numerical data
numerical_data.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price      Year  \
# Rating    1.000000  0.050106  0.050348  0.036118 -0.016476  0.102311
# Reviews   0.050106  1.000000  0.077528  0.625164 -0.007599  0.058081
# Size      0.050348  0.077528  1.000000  0.042935 -0.021810  0.196426
# Installs  0.036118  0.625164  0.042935  1.000000 -0.009406  0.068849
# Price    -0.016476 -0.007599 -0.021810 -0.009406  1.000000 -0.003604
# Year      0.102311  0.058081  0.196426  0.068849 -0.003604  1.000000
# Month     0.019802  0.036539  0.031295  0.043176  0.007347 -0.199901
# Date     -0.004405 -0.033086 -0.009913 -0.042020 -0.009098 -0.015150
#
#              Month      Date
# Rating    0.019802 -0.004405
# Reviews   0.036539 -0.033086
# Size      0.031295 -0.009913
# Installs  0.043176 -0.042020
# Price     0.007347 -0.009098
# Year     -0.199901 -0.015150
# Month     1.000000 -0.066553
# Date     -0.066553  1.000000

# %%
correlation_matrix=numerical_data.corr()

# %%
plt.figure(figsize=(12,8),dpi=80)
plt.title('Heat map of numerical columns')
sns.heatmap(correlation_matrix,annot=True)
# Out:
# <AxesSubplot:title={'center':'Heat map of numerical columns'}>

# %% [markdown]
#  - by this heatmap we have conclude as ***installs*** is highly co-related with ***reviews*** with value of .63
#  - corelation between ***Installs*** and ***Reviews*** is positive

# %%
sns.scatterplot(x=numerical_data["Installs"],y=numerical_data["Reviews"])
# Out:
# <AxesSubplot:xlabel='Installs', ylabel='Reviews'>

# %% [markdown]
# # Category column

# %%
catogorical_data["Category"].value_counts()
# Out:
# FAMILY                 1831
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# ART_AND_DESIGN           64
# EVENTS                   64
# PARENTING                60
# COMICS                   56
# BEAUTY                   53
# Name: Category, dtype: int64

# %% [markdown]
# # Which are the top 10  categories that has the maximum number of apps

# %%
plt.figure(figsize=(12, 8), dpi=80)
plt.xticks(rotation=90) 
plt.title(' top 10 categories that has the maximum number of apps')
plt.ylabel('No of Apps')
sns.countplot(x="Category",data=catogorical_data,hue="Content Rating",order=catogorical_data['Category'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:title={'center':' top 10 categories that has the maximum number of apps'}, xlabel='Category', ylabel='count'>

# %% [markdown]
#  - These are top 10 categories in which maximum apps have been developed

# %% [markdown]
# # Which are the top 10 apps has made more profit?
#  1. To calculate the profit of apps
#      - You need to filter paid apps
#      - Multiply price with installs to get total profit

# %%
play_store_paid=playstore_data[playstore_data["Type"]=="Paid"]

# %%
play_store_paid["Total_profit"]=play_store_paid["Installs"]*play_store_paid["Price"]
# Out:
# <ipython-input-1491-49b876cb3a78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   play_store_paid["Total_profit"]=play_store_paid["Installs"]*play_store_paid["Price"]

# %%
play_store_paid.sort_values("Total_profit",ascending=False).head(10)
# Out:
#                                 App     Category  Rating  Reviews      Size  \
# 2241                      Minecraft       FAMILY     4.5  73482.5  28319.25
# 5351                      I am rich    LIFESTYLE     3.8   3547.0   1800.00
# 5356              I Am Rich Premium      FINANCE     4.1   1867.0   4700.00
# 4034                  Hitman Sniper         GAME     4.6  73482.5  29000.00
# 7417  Grand Theft Auto: San Andreas         GAME     4.4  73482.5  26000.00
# 2883            Facetune - For Free  PHOTOGRAPHY     4.4  49553.0  48000.00
# 5578        Sleep as Android Unlock    LIFESTYLE     4.5  23966.0    872.00
# 8804            DraStic DS Emulator         GAME     4.6  73482.5  12000.00
# 4367       I'm Rich - Trump Edition    LIFESTYLE     3.6    275.0   7300.00
# 5354                 I am Rich Plus       FAMILY     4.0    856.0   8700.00
#
#       Installs  Type   Price Content Rating                     Genres  \
# 2241  10000000  Paid    6.99   Everyone 10+  Arcade;Action & Adventure
# 5351    100000  Paid  399.99       Everyone                  Lifestyle
# 5356     50000  Paid  399.99       Everyone                    Finance
# 4034  10000000  Paid    0.99     Mature 17+                     Action
# 7417   1000000  Paid    6.99     Mature 17+                     Action
# 2883   1000000  Paid    5.99       Everyone                Photography
# 5578   1000000  Paid    5.99       Everyone                  Lifestyle
# 8804   1000000  Paid    4.99       Everyone                     Action
# 4367     10000  Paid  400.00       Everyone                  Lifestyle
# 5354     10000  Paid  399.99       Everyone              Entertainment
#
#      Last Updated Current Ver         Android Ver  Year  Month  Date  \
# 2241   2018-07-24     1.5.2.1  Varies with device  2018      7    24
# 5351   2018-01-12         2.0        4.0.3 and up  2018      1    12
# 5356   2017-11-12         1.6          4.0 and up  2017     11    12
# 4034   2018-07-12  1.7.110758          4.1 and up  2018      7    12
# 7417   2015-03-21        1.08          3.0 and up  2015      3    21
# 2883   2018-07-25       1.3.1          4.1 and up  2018      7    25
# 5578   2018-06-27    20180608          4.0 and up  2018      6    27
# 8804   2016-07-19   r2.5.0.3a          2.3 and up  2016      7    19
# 4367   2018-05-03       1.0.1          4.1 and up  2018      5     3
# 5354   2018-05-19         3.0          4.4 and up  2018      5    19
#
#       Total_profit
# 2241    69900000.0
# 5351    39999000.0
# 5356    19999500.0
# 4034     9900000.0
# 7417     6990000.0
# 2883     5990000.0
# 5578     5990000.0
# 8804     4990000.0
# 4367     4000000.0
# 5354     3999900.0

# %%
plt.figure(figsize=(12, 8), dpi=80)
plt.xticks(rotation=75,)
plt.title('Top 10 apps making most of the revenue')
plt.ylabel('Total Profit')
sns.barplot(x="App",y='Total_profit',data=play_store_paid.sort_values("Total_profit",ascending=False).head(10))
# Out:
# <AxesSubplot:title={'center':'Top 10 apps making most of the revenue'}, xlabel='App', ylabel='Total_profit'>

# %% [markdown]
# - These are the top 10 apps making profit <br>
# Conclusion - Maximum profit making app is from GAME category

# %%
sns.pairplot(numerical_data[["Size","Price","Rating","Reviews","Installs"]])

# %% [markdown]
# ### (play_store_paid) is a dataframe that contains only apps under paid category

# %% [markdown]
# # What is the common range of price that most of the apps have?

# %%
plt.hist(play_store_paid["Price"],bins=20,range=[0,15])
plt.title('Visualizing the distribution of price for Paid Apps')
plt.title('Most Purchased Category (Paid Apps)')
plt.ylabel('No of Apps')
plt.xlabel('Distribution of Prices in $ Dollars')
plt.show()

# %% [markdown]
#  - by this histogram plot above we can conclude that people tend to buy the apps with less price
#  - i.e the price range between 1 and 6 dollars <br>

# %% [markdown]
# # What is the range of price that maximum customers tend to buy?

# %%
sns.scatterplot(x=play_store_paid["Price"],y=play_store_paid["Installs"])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Installs'>

# %% [markdown]
# - By this scatterplot we can conclude that apps with lesser price are installed more
# - i.e lesser the price more the installs ***(purchase)*** are more
# - if one variable increases and other variables decrease that means we it negative coorelation <br>
# the negative corelation between the Installs and price is not clearly visible in graph <br>
# But we can see the proof in below two cells

# %%
# Printing the average number of installs for the apps having price below 12 dollor
play_store_paid[play_store_paid["Price"]< 12]["Installs"].mean()
# Out:
# 82461.34497816594

# %%
# Printing the average number of installs for the apps having price above 12 dollor
play_store_paid[play_store_paid["Price"]> 12]["Installs"].mean()
# Out:
# 10346.91304347826

# %% [markdown]
# - average  of installs for apps having price below 12 dollar is approximately around 82460
# - average of installs for apps having price more than 12 dollars is approximately arounf 10346 <br>
#
# - By this relation of less price more installs and more price less installs
# - we can tell that installs and price are negatively co-related
#
# Conclusion Need to keep less price for high probability of apps to get purchased

# %%
play_store_paid.corr()
# Out:
#                 Rating   Reviews      Size  Installs     Price      Year  \
# Rating        1.000000  0.145521  0.106155  0.059706 -0.112955  0.100900
# Reviews       0.145521  1.000000  0.192935  0.520759 -0.052577  0.063426
# Size          0.106155  0.192935  1.000000  0.090700 -0.065985  0.187386
# Installs      0.059706  0.520759  0.090700  1.000000 -0.021525  0.060151
# Price        -0.112955 -0.052577 -0.065985 -0.021525  1.000000  0.092848
# Year          0.100900  0.063426  0.187386  0.060151  0.092848  1.000000
# Month         0.005408  0.065947  0.028133  0.027199  0.026759 -0.157850
# Date         -0.011410 -0.043392 -0.005302 -0.000486 -0.034106  0.011861
# Total_profit  0.002122  0.312115  0.015838  0.672686  0.228689  0.063345
#
#                  Month      Date  Total_profit
# Rating        0.005408 -0.011410      0.002122
# Reviews       0.065947 -0.043392      0.312115
# Size          0.028133 -0.005302      0.015838
# Installs      0.027199 -0.000486      0.672686
# Price         0.026759 -0.034106      0.228689
# Year         -0.157850  0.011861      0.063345
# Month         1.000000 -0.106067     -0.008831
# Date         -0.106067  1.000000      0.016512
# Total_profit -0.008831  0.016512      1.000000

# %%
plt.figure(figsize=(12,8),dpi=80)
plt.title('Heatmap of paid apps')
sns.heatmap(play_store_paid.corr(),annot=True)
# Out:
# <AxesSubplot:title={'center':'Heatmap of paid apps'}>

# %% [markdown]
# # Which category of paid apps have most of the purchases ?

# %%
mean_installs=play_store_paid.groupby("Category")["Installs"].mean().reset_index()
mean_installs
# Out:
#                Category       Installs
# 0        ART_AND_DESIGN    5333.333333
# 1     AUTO_AND_VEHICLES   16716.666667
# 2   BOOKS_AND_REFERENCE     832.714286
# 3              BUSINESS   17731.250000
# 4         COMMUNICATION   50372.222222
# 5                DATING    1891.666667
# 6             EDUCATION  150500.000000
# 7         ENTERTAINMENT  100000.000000
# 8                EVENTS       1.000000
# 9                FAMILY  112840.513661
# 10              FINANCE   10917.764706
# 11       FOOD_AND_DRINK   30000.000000
# 12                 GAME  256097.134146
# 13   HEALTH_AND_FITNESS   31607.333333
# 14   LIBRARIES_AND_DEMO     100.000000
# 15            LIFESTYLE   62058.421053
# 16  MAPS_AND_NAVIGATION   24220.000000
# 17              MEDICAL    6757.024096
# 18   NEWS_AND_MAGAZINES    2750.000000
# 19            PARENTING   25050.000000
# 20      PERSONALIZATION   40232.024691
# 21          PHOTOGRAPHY   98881.052632
# 22         PRODUCTIVITY   50430.535714
# 23             SHOPPING    5050.000000
# 24               SOCIAL    2000.000000
# 25               SPORTS   51825.625000
# 26                TOOLS   22146.679487
# 27     TRAVEL_AND_LOCAL   15255.000000
# 28        VIDEO_PLAYERS   17750.000000
# 29              WEATHER  101500.000000

# %%
plt.figure(figsize=(8,6),dpi=80)
plt.title('Most Purchased Category (Paid Apps)')
sns.barplot(x="Installs",y="Category",data=mean_installs.sort_values('Installs',ascending=False).head())
plt.show()

# %% [markdown]
#  - The top 5 categories that have most of the purchases <br>
#  Conclusion If you need to make profit from paid apps its better to develop upon these top 5 categories

# %% [markdown]
# # Analysis on data
# # Which are top 10 categories that has most paid apps in it

# %%
plt.figure(figsize=(16,8),dpi=80)
plt.xticks(rotation=75)
plt.title('Paid Apps:Top 10 Apps based on Category')
sns.countplot(x="Category",hue="Content Rating",data=play_store_paid,order=play_store_paid["Category"].value_counts().iloc[:10].index)
plt.show()

# %% [markdown]
#  - these are catogories that have most of paid apps
#  - The top 3 are
#      1. Family
#      2. Medical
#      3. Game

# %% [markdown]
# # Now lets concentrate on over all apps
#
#  - Ratings and Installs are the key factors that determines the usage and quality of the apps

# %% [markdown]
# # Which Category app has been more installed?

# %%
most_downloaded_category=playstore_data.groupby(["Category"])["Installs"].sum().sort_values(ascending=False).reset_index()
most_downloaded_category
# Out:
#                Category     Installs
# 0                  GAME  13878924415
# 1         COMMUNICATION  11038276251
# 2                 TOOLS   8001771915
# 3          PRODUCTIVITY   5793091369
# 4                SOCIAL   5487867902
# 5           PHOTOGRAPHY   4649147655
# 6                FAMILY   4427941505
# 7         VIDEO_PLAYERS   3926902720
# 8      TRAVEL_AND_LOCAL   2894887146
# 9    NEWS_AND_MAGAZINES   2369217760
# 10        ENTERTAINMENT   2113660000
# 11  BOOKS_AND_REFERENCE   1665969576
# 12      PERSONALIZATION   1532494782
# 13             SHOPPING   1400348785
# 14   HEALTH_AND_FITNESS   1144022512
# 15               SPORTS   1096474498
# 16             BUSINESS    697164865
# 17            LIFESTYLE    503823539
# 18  MAPS_AND_NAVIGATION    503281890
# 19              FINANCE    455348734
# 20              WEATHER    361100520
# 21            EDUCATION    352952000
# 22       FOOD_AND_DRINK    211798751
# 23               DATING    140926107
# 24       ART_AND_DESIGN    114338100
# 25       HOUSE_AND_HOME     97212461
# 26    AUTO_AND_VEHICLES     53130211
# 27   LIBRARIES_AND_DEMO     52995910
# 28               COMICS     44981150
# 29              MEDICAL     38193177
# 30            PARENTING     31521110
# 31               BEAUTY     27197050
# 32               EVENTS     15973161

# %%
plt.figure(figsize=(12,8),dpi=80)
plt.xticks(rotation=45)
plt.title('Total Number Installs(Sum) Vs Category')
sns.barplot(y="Installs",x="Category",data=most_downloaded_category.head(10))
# Out:
# <AxesSubplot:title={'center':'Total Number Installs(Sum) Vs Category'}, xlabel='Category', ylabel='Installs'>

# %% [markdown]
# - These are top 10 category most downloaded
# - Game category has most number of downloads

# %% [markdown]
# # Which category is mosted rated ,which category apps are appreciated by customers, and mention the category in which more improvement is needed to reach customer's expectation?

# %%
mean_rating=playstore_data.groupby("Category")["Rating"].mean().reset_index()

# %%
plt.figure(figsize=(16,8),dpi=80)
plt.title('Rating Vs Category')
plt.ylabel("average of rating")
plt.xticks(rotation=75)
sns.lineplot(y="Rating",x="Category",data=mean_rating)
# Out:
# <AxesSubplot:title={'center':'Rating Vs Category'}, xlabel='Category', ylabel='average of rating'>

# %% [markdown]
# -  Positive Feedback
#  - Apps based on ***Event*** and ***Education*** Category has more average rating compared to all other apps
# - Negative Feedback
#  - Apps related to categories like ***Dating***, ***Maps and*** ***Navigation*** and ***Videoplayer*** need more improvement towards its quality and service towards the customers

# %% [markdown]
# # Display the proportion of the Content rating and show which related Content rating is maximum amoung apps

# %%
data_for_pie=playstore_data['Content Rating'].value_counts().reset_index()
data_for_pie["% of apps"]=(data_for_pie['Content Rating']/data_for_pie['Content Rating'].sum())*100
data_for_pie
# Out:
#              index  Content Rating  % of apps
# 0         Everyone            7903  81.828536
# 1             Teen            1036  10.726859
# 2       Mature 17+             393   4.069165
# 3     Everyone 10+             321   3.323669
# 4  Adults only 18+               3   0.031062
# 5          Unrated               2   0.020708

# %%
plt.figure(figsize=(12,8),dpi=80)
colors = sns.color_palette('pastel')[0:data_for_pie.shape[0]]
plt.title('Pie Chart on apps Based on Content Rating')
explode=[0,0.2,0.2,0.2,0.2,0]
plt.pie(data_for_pie["Content Rating"],labels=data_for_pie["index"],explode=explode,colors=colors,autopct='%.2f%%')
plt.show()

# %% [markdown]
#  - visualizing the apps proportion
#   - 80% of all the apps can be used by Everyone
#   - Investing time must be less for development on Other apps having Content rating other an ***Everyone*** becasue it has less exposure

# %%
playstore_data.describe()
# Out:
#             Rating       Reviews          Size      Installs        Price  \
# count  9658.000000   9658.000000   9658.000000  9.658000e+03  9658.000000
# mean      4.210561  18632.613481  19019.319704  7.778312e+06     1.099413
# std       0.430532  28324.370733  17134.712893  5.376100e+07    16.853021
# min       3.250000      0.000000      8.500000  0.000000e+00     0.000000
# 25%       4.000000     25.000000   5300.000000  1.000000e+03     0.000000
# 50%       4.300000    967.000000  13217.535000  1.000000e+05     0.000000
# 75%       4.500000  29408.000000  27000.000000  1.000000e+06     0.000000
# max       5.000000  73482.500000  59550.000000  1.000000e+09   400.000000
#
#              Year        Month         Date
# count  9658.00000  9658.000000  9658.000000
# mean   2017.34562     6.364051    15.631704
# std       1.13764     2.659746     9.430666
# min    2010.00000     1.000000     1.000000
# 25%    2017.00000     5.000000     7.000000
# 50%    2018.00000     7.000000    16.000000
# 75%    2018.00000     8.000000    24.000000
# max    2018.00000    12.000000    31.000000

# %% [markdown]
# # Find out Probability or range of age whos uses the apps most?
# (Like above 18+ or below 18)

# %%
rate_installs_content_rating=playstore_data.groupby("Content Rating")["Installs"].mean().sort_values(ascending=False)

# %%
plt.figure(figsize=(12,8),dpi=180)
plt.title('Apps usage based on Content Rating')
sns.barplot(y=rate_installs_content_rating,x=rate_installs_content_rating.index)
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='Installs'>

# %% [markdown]
#  - ***Teen*** Content Rated is mostly downloaded then ***Everyone 10+*** followed by ***Everyone*** <br>
#  There is probability of Max downloads of apps are used by non adults (below 17) as Mature 17+ and Adults 18+ cannot be used by them
#
#  Conclusion- Develop Apps that will appropriate for under ages also to use again you wll get more Installs

# %% [markdown]
# # Find out if customers who installed apps are feeling the size of the app as burden?

# %%
plt.title('Rating vs Size')
sns.scatterplot(x='Size',y="Rating",data=playstore_data)
# Out:
# <AxesSubplot:title={'center':'Rating vs Size'}, xlabel='Size', ylabel='Rating'>

# %% [markdown]
#  - There is no much negative or positive trend seen in this graph
#  - Hence the customer are not feeling the size of the app as burden
#  - If so those customers are very negligible

# %% [markdown]
# # Which out which of the genres is appreciated and which genres need improvement

# %%
genre_rating_mean=playstore_data.groupby("Genres")["Rating"].mean().sort_values(ascending=False)

# %%
plt.figure(figsize=(12,8),dpi=180)
plt.title('Apps with Best Rating')
plt.xticks(rotation=90)
sns.lineplot(y=genre_rating_mean.head(10),x=genre_rating_mean.head(10).index)
# Out:
# <AxesSubplot:title={'center':'Apps with Best Rating'}, xlabel='Genres', ylabel='Rating'>

# %% [markdown]
#  - ***Comics:Creativity*** Genre related app has more rating followed by ***Board:Pretend Play*** and ***Health*** <br>
#  These genre related apps are much appreciated

# %%
plt.figure(figsize=(12,8),dpi=180)
plt.xticks(rotation=90)
plt.title('Apps with Low Rating')
sns.lineplot(y=genre_rating_mean.tail(10),x=genre_rating_mean.tail(10).index)
# Out:
# <AxesSubplot:title={'center':'Apps with Low Rating'}, xlabel='Genres', ylabel='Rating'>

# %% [markdown]
#  - Apps related to genre like ***RolePlaying Education***, ***Parenting Brain Games*** <br>
#  and other genres related apps above must be improved

# %%
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews      Size  Installs  Type  Price Content Rating  \
# 0         4.1    159.0  19000.00     10000  Free    0.0       Everyone
# 1         3.9    967.0  14000.00    500000  Free    0.0       Everyone
# 2         4.7  73482.5   8700.00   5000000  Free    0.0       Everyone
# 3         4.5  73482.5  25000.00  50000000  Free    0.0           Teen
# 4         4.3    967.0   2800.00    100000  Free    0.0       Everyone
# ...       ...      ...       ...       ...   ...    ...            ...
# 10836     4.5     38.0  53000.00      5000  Free    0.0       Everyone
# 10837     5.0      4.0   3600.00       100  Free    0.0       Everyone
# 10838     4.4      3.0   9500.00      1000  Free    0.0       Everyone
# 10839     4.5    114.0  13310.82      1000  Free    0.0     Mature 17+
# 10840     4.5  73482.5  19000.00  10000000  Free    0.0       Everyone
#
#                           Genres Last Updated         Current Ver  \
# 0                   Art & Design   2018-01-07               1.0.0
# 1      Art & Design;Pretend Play   2018-01-15               2.0.0
# 2                   Art & Design   2018-08-01               1.2.4
# 3                   Art & Design   2018-06-08  Varies with device
# 4        Art & Design;Creativity   2018-06-20                 1.1
# ...                          ...          ...                 ...
# 10836                  Education   2017-07-25                1.48
# 10837                  Education   2018-07-06                 1.0
# 10838                    Medical   2017-01-20                 1.0
# 10839          Books & Reference   2015-01-19  Varies with device
# 10840                  Lifestyle   2018-07-25  Varies with device
#
#               Android Ver  Year  Month  Date
# 0            4.0.3 and up  2018      1     7
# 1            4.0.3 and up  2018      1    15
# 2            4.0.3 and up  2018      8     1
# 3              4.2 and up  2018      6     8
# 4              4.4 and up  2018      6    20
# ...                   ...   ...    ...   ...
# 10836          4.1 and up  2017      7    25
# 10837          4.1 and up  2018      7     6
# 10838          2.2 and up  2017      1    20
# 10839  Varies with device  2015      1    19
# 10840  Varies with device  2018      7    25
#
# [9658 rows x 16 columns]

# %%
month_install_mean=playstore_data.groupby('Month')["Installs"].mean()
month_install_mean
# Out:
# Month
# 1     2.198909e+06
# 2     1.488107e+06
# 3     1.396981e+06
# 4     2.531348e+06
# 5     3.934097e+06
# 6     4.152566e+06
# 7     1.096677e+07
# 8     2.414868e+07
# 9     1.356086e+06
# 10    1.179058e+06
# 11    2.472744e+06
# 12    2.492907e+06
# Name: Installs, dtype: float64

# %%
plt.title('Count of Apps Last Updated on Every Month')
sns.countplot(x=playstore_data["Month"])
# Out:
# <AxesSubplot:title={'center':'Count of Apps Last Updated on Every Month'}, xlabel='Month', ylabel='count'>

# %%
plt.figure(figsize=(12,8),dpi=80)
plt.title('Installs vs Month')
labels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
plt.xticks(month_install_mean.index,labels=values)
sns.lineplot(y=month_install_mean,x=month_install_mean.index)
# Out:
# <AxesSubplot:title={'center':'Installs vs Month'}, xlabel='Month', ylabel='Installs'>

# %% [markdown]
#  - Max updates for the apps used to release at the month of ***July*** and ***August***
#  - In every year we can see that there is raise in ***Installs*** in the Month of ***July*** and ***August***
#
#  - The Max Apps are getting an updated version in the month of ***July*** and ***August*** and hence we can see more downloads on the same time

# %% [markdown]
# # Data Visualization of second dataset user reviews

# %%
user_reviews.tail(25)
# Out:
#                                   App  \
# 64190  Hotwire Hotel & Car Rental App
# 64191  Hotwire Hotel & Car Rental App
# 64192  Hotwire Hotel & Car Rental App
# 64194  Hotwire Hotel & Car Rental App
# 64196  Housing-Real Estate & Property
# 64197  Housing-Real Estate & Property
# 64198  Housing-Real Estate & Property
# 64199  Housing-Real Estate & Property
# 64200  Housing-Real Estate & Property
# 64201  Housing-Real Estate & Property
# 64205  Housing-Real Estate & Property
# 64207  Housing-Real Estate & Property
# 64209  Housing-Real Estate & Property
# 64213  Housing-Real Estate & Property
# 64215  Housing-Real Estate & Property
# 64216  Housing-Real Estate & Property
# 64217  Housing-Real Estate & Property
# 64218  Housing-Real Estate & Property
# 64220  Housing-Real Estate & Property
# 64221  Housing-Real Estate & Property
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 64190                        Find good price car rental.  Positive
# 64191  Very simple, straight forward, good ui....even...  Positive
# 64192                                        Great deals  Positive
# 64194  Keeps telling there's problem date time, can't...   Neutral
# 64196  Incorrect listings. The agents show property d...  Negative
# 64197  Pathetic app.All posted leads owner either old...  Negative
# 64198  It's waste app... Most properties 2017... And ...  Positive
# 64199  Filters useless I posted owners shows agents a...  Negative
# 64200  Why business? Your filters don't work.. redire...   Neutral
# 64201         Filters work... Searching property useless  Negative
# 64205   I want list property sale option. Please connect   Neutral
# 64207                                               Good  Positive
# 64209  Awesome app.. But prices date? Awesome app. Gi...  Positive
# 64213  This worse ever. They give graphic pictures pr...  Negative
# 64215  Horrible app. I wanted list property get aroun...  Negative
# 64216  Worst app. We get nothing Time waste . They up...  Negative
# 64217  I able set range 1cr, scroll space 0-1cr range...  Positive
# 64218  What nonsensical app.. doesn't owner postings ...   Neutral
# 64220  No response support team. After I login, unabl...  Negative
# 64221  Everything old stuff neither clear sold proper...  Positive
# 64222  Most ads older many agents ..not much owner po...  Positive
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64190            0.700000                0.600000
# 64191            0.350000                0.491071
# 64192            0.800000                0.750000
# 64194            0.000000                0.000000
# 64196           -0.025000                0.125000
# 64197           -0.362500                0.625000
# 64198            0.266667                0.375000
# 64199           -0.500000                0.200000
# 64200            0.000000                0.000000
# 64201           -0.500000                0.200000
# 64205            0.000000                0.000000
# 64207            0.700000                0.600000
# 64209            0.509375                0.511458
# 64213           -0.081250                0.418750
# 64215           -0.528571                0.717262
# 64216           -0.400000                0.250000
# 64217            0.233333                0.550000
# 64218            0.000000                0.000000
# 64220           -0.377778                0.533333
# 64221            0.021591                0.259470
# 64222            0.173333                0.486667
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000

# %%
user_reviews.corr()
# Out:
#                         Sentiment_Polarity  Sentiment_Subjectivity
# Sentiment_Polarity                1.000000                0.261587
# Sentiment_Subjectivity            0.261587                1.000000

# %%
sns.pairplot(user_reviews)

# %%
sentiment_proportion=user_reviews["Sentiment"].value_counts()

# %%
plt.figure(figsize=(12,8),dpi=80)
plt.title('Proportion of Apps on Sentiment')
plt.pie(x=user_reviews["Sentiment"].value_counts(),labels=sentiment_proportion.index,autopct="%.2f%%",explode=[0,0.02,0.02])
plt.show()

# %% [markdown]
#  - Most of the apps have positive feedback from the customers

# %% [markdown]
# # Now Lets merge the two dataset and check the sentiments of people on the apps category genres etc

# %%
combined_data=pd.merge(user_reviews,playstore_data,how="left",on="App")

# %%
combined_data.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You         Works great especially going grocery store
# 3  10 Best Foods for You                                       Best idea us
# 4  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity            Category  \
# 0  Positive                1.00                0.533333  HEALTH_AND_FITNESS
# 1  Positive                0.25                0.288462  HEALTH_AND_FITNESS
# 2  Positive                0.40                0.875000  HEALTH_AND_FITNESS
# 3  Positive                1.00                0.300000  HEALTH_AND_FITNESS
# 4  Positive                1.00                0.300000  HEALTH_AND_FITNESS
#
#    Rating  Reviews    Size  Installs  Type  Price Content Rating  \
# 0     4.0   2490.0  3800.0  500000.0  Free    0.0   Everyone 10+
# 1     4.0   2490.0  3800.0  500000.0  Free    0.0   Everyone 10+
# 2     4.0   2490.0  3800.0  500000.0  Free    0.0   Everyone 10+
# 3     4.0   2490.0  3800.0  500000.0  Free    0.0   Everyone 10+
# 4     4.0   2490.0  3800.0  500000.0  Free    0.0   Everyone 10+
#
#              Genres Last Updated Current Ver   Android Ver    Year  Month  \
# 0  Health & Fitness   2017-02-17         1.9  2.3.3 and up  2017.0    2.0
# 1  Health & Fitness   2017-02-17         1.9  2.3.3 and up  2017.0    2.0
# 2  Health & Fitness   2017-02-17         1.9  2.3.3 and up  2017.0    2.0
# 3  Health & Fitness   2017-02-17         1.9  2.3.3 and up  2017.0    2.0
# 4  Health & Fitness   2017-02-17         1.9  2.3.3 and up  2017.0    2.0
#
#    Date
# 0  17.0
# 1  17.0
# 2  17.0
# 3  17.0
# 4  17.0

# %%
combined_data.shape
# Out:
# (37427, 20)

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37427 entries, 0 to 37426
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     37427 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37427 non-null  object
#  3   Sentiment_Polarity      37427 non-null  float64
#  4   Sentiment_Subjectivity  37427 non-null  float64
#  5   Category                35929 non-null  object
#  6   Rating                  35929 non-null  float64
#  7   Reviews                 35929 non-null  float64
#  8   Size                    35929 non-null  float64
#  9   Installs                35929 non-null  float64
#  10  Type                    35929 non-null  object
#  11  Price                   35929 non-null  float64
#  12  Content Rating          35929 non-null  object
#  13  Genres                  35929 non-null  object
#  14  Last Updated            35929 non-null  datetime64[ns]
#  15  Current Ver             35929 non-null  object
#  16  Android Ver             35929 non-null  object
#  17  Year                    35929 non-null  float64
#  18  Month                   35929 non-null  float64
#  19  Date                    35929 non-null  float64
# dtypes: datetime64[ns](1), float64(10), object(9)
# memory usage: 7.0+ MB

# %% [markdown]
# ## Removing null values

# %%
combined_data.dropna(how="any",inplace=True)

# %%
combined_data[combined_data.isna()]
# Out:
#        App Translated_Review Sentiment  Sentiment_Polarity  \
# 0      NaN               NaN       NaN                 NaN
# 1      NaN               NaN       NaN                 NaN
# 2      NaN               NaN       NaN                 NaN
# 3      NaN               NaN       NaN                 NaN
# 4      NaN               NaN       NaN                 NaN
# ...    ...               ...       ...                 ...
# 37422  NaN               NaN       NaN                 NaN
# 37423  NaN               NaN       NaN                 NaN
# 37424  NaN               NaN       NaN                 NaN
# 37425  NaN               NaN       NaN                 NaN
# 37426  NaN               NaN       NaN                 NaN
#
#        Sentiment_Subjectivity Category  Rating  Reviews  Size  Installs Type  \
# 0                         NaN      NaN     NaN      NaN   NaN       NaN  NaN
# 1                         NaN      NaN     NaN      NaN   NaN       NaN  NaN
# 2                         NaN      NaN     NaN      NaN   NaN       NaN  NaN
# 3                         NaN      NaN     NaN      NaN   NaN       NaN  NaN
# 4                         NaN      NaN     NaN      NaN   NaN       NaN  NaN
# ...                       ...      ...     ...      ...   ...       ...  ...
# 37422                     NaN      NaN     NaN      NaN   NaN       NaN  NaN
# 37423                     NaN      NaN     NaN      NaN   NaN       NaN  NaN
# 37424                     NaN      NaN     NaN      NaN   NaN       NaN  NaN
# 37425                     NaN      NaN     NaN      NaN   NaN       NaN  NaN
# 37426                     NaN      NaN     NaN      NaN   NaN       NaN  NaN
#
#        Price Content Rating Genres Last Updated Current Ver Android Ver  Year  \
# 0        NaN            NaN    NaN          NaT         NaN         NaN   NaN
# 1        NaN            NaN    NaN          NaT         NaN         NaN   NaN
# 2        NaN            NaN    NaN          NaT         NaN         NaN   NaN
# 3        NaN            NaN    NaN          NaT         NaN         NaN   NaN
# 4        NaN            NaN    NaN          NaT         NaN         NaN   NaN
# ...      ...            ...    ...          ...         ...         ...   ...
# 37422    NaN            NaN    NaN          NaT         NaN         NaN   NaN
# 37423    NaN            NaN    NaN          NaT         NaN         NaN   NaN
# 37424    NaN            NaN    NaN          NaT         NaN         NaN   NaN
# 37425    NaN            NaN    NaN          NaT         NaN         NaN   NaN
# 37426    NaN            NaN    NaN          NaT         NaN         NaN   NaN
#
#        Month  Date
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
# ...      ...   ...
# 37422    NaN   NaN
# 37423    NaN   NaN
# 37424    NaN   NaN
# 37425    NaN   NaN
# 37426    NaN   NaN
#
# [37427 rows x 20 columns]

# %%
combined_data.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity        Rating       Reviews  \
# count        35929.000000            35929.000000  35929.000000  35929.000000
# mean             0.180904                0.493767      4.299747  45262.467171
# std              0.350080                0.258053      0.292353  30797.234034
# min             -1.000000                0.000000      3.250000    114.000000
# 25%              0.000000                0.361111      4.100000  10247.000000
# 50%              0.150000                0.514835      4.300000  64513.000000
# 75%              0.400000                0.650000      4.500000  73482.500000
# max              1.000000                1.000000      4.900000  73482.500000
#
#                Size      Installs         Price          Year         Month  \
# count  35929.000000  3.592900e+04  35929.000000  35929.000000  35929.000000
# mean   24651.250851  4.377751e+07      0.109197   2017.728965      6.741908
# std    17675.085937  1.453414e+08      1.302471      0.795652      1.785850
# min        8.500000  1.000000e+03      0.000000   2011.000000      1.000000
# 25%    11766.710000  1.000000e+06      0.000000   2018.000000      6.000000
# 50%    19629.040000  5.000000e+06      0.000000   2018.000000      7.000000
# 75%    37000.000000  1.000000e+07      0.000000   2018.000000      8.000000
# max    59550.000000  1.000000e+09     29.990000   2018.000000     12.000000
#
#                Date
# count  35929.000000
# mean      15.443430
# std       10.199869
# min        1.000000
# 25%        5.000000
# 50%       16.000000
# 75%       25.000000
# max       31.000000

# %% [markdown]
# # Find the top 10 apps having most positive  and most negative feedback that has got more than 100 feedbacks

# %%
positive_count=combined_data.groupby("App").apply(lambda x : x[x["Sentiment"]=="Positive"]["Sentiment"].count())

# %%
# a["Total_feedback"]=
total_count=combined_data.groupby("App")["Sentiment_Polarity"].count()

# %%
feedback_table=pd.DataFrame({"postive_feedback":positive_count,"TotalFeedback":total_count ,
              "Percentage of positive FeedBack":round((positive_count/total_count)*100,2)})

# %%
top_10_pos_feedback=feedback_table[feedback_table["TotalFeedback"]>100].sort_values(["Percentage of positive FeedBack"],ascending=False).head(10).reset_index()
top_10_pos_feedback
# Out:
#                               App  postive_feedback  TotalFeedback  \
# 0         ColorNote Notepad Notes               121            131
# 1            DC Super Hero Girls™                90            102
# 2  Crunchyroll - Everything Anime               105            120
# 3        Calorie Counter - Macros               174            200
# 4    Calorie Counter - MyNetDiary               120            139
# 5           10 Best Foods for You               162            194
# 6  Duolingo: Learn Languages Free               200            240
# 7    Family Locator - GPS Tracker                95            115
# 8  Calorie Counter & Diet Tracker               109            135
# 9    8fit Workouts & Meal Planner               137            171
#
#    Percentage of positive FeedBack
# 0                            92.37
# 1                            88.24
# 2                            87.50
# 3                            87.00
# 4                            86.33
# 5                            83.51
# 6                            83.33
# 7                            82.61
# 8                            80.74
# 9                            80.12

# %%
plt.figure(figsize=(12,8),dpi=80)
plt.xticks(rotation=75)
plt.title('Top 10 Apps With Most Positive Feedback  ')
sns.barplot(data=top_10_pos_feedback,y="Percentage of positive FeedBack",x="App")
# Out:
# <AxesSubplot:title={'center':'Top 10 Apps With Most Positive Feedback  '}, xlabel='App', ylabel='Percentage of positive FeedBack'>

# %% [markdown]
#  - These are the top 10 apps with that has max percentage of positive feedback with minimun 100 feedbacks

# %%
top_10_neg_feedback=feedback_table[feedback_table["TotalFeedback"]>100].sort_values(["Percentage of positive FeedBack"],ascending=False).tail(10).reset_index()
top_10_neg_feedback
# Out:
#                               App  postive_feedback  TotalFeedback  \
# 0        Booking.com Travel Deals                54            120
# 1  Gyft - Mobile Gift Card Wallet                54            120
# 2                         Agar.io                60            136
# 3                Candy Crush Saga               102            240
# 4                Farm Heroes Saga                46            110
# 5                   Cooking Fever                55            135
# 6                Fashion in Vogue                46            113
# 7                        Facebook                53            132
# 8           Candy Crush Soda Saga                62            166
# 9           BET NOW - Watch Shows                39            108
#
#    Percentage of positive FeedBack
# 0                            45.00
# 1                            45.00
# 2                            44.12
# 3                            42.50
# 4                            41.82
# 5                            40.74
# 6                            40.71
# 7                            40.15
# 8                            37.35
# 9                            36.11

# %%
plt.figure(figsize=(12,6),dpi=80)
plt.xticks(rotation=75)
plt.title('Top 10 Apps having Most Percentage of Negative Feedback  ')

sns.barplot(data=top_10_pos_feedback,y="Percentage of positive FeedBack",x="App")
plt.show()
# px.bar(top_10_pos_feedback,y="Percentage of positive FeedBack",x="App",color=px.colors.qualitative.Plotly)

# %% [markdown]
#   - These are the top 10 apps with that has max percentage of negative feedback with minimun 100 feedbacks

# %% [markdown]
#  # What category has more size compared to each other?

# %%
plt.figure(figsize=(14,4))
sns.boxplot(x='Category', y='Size', data=playstore_data, hue='Type')
plt.xticks(rotation=90);
plt.title('size vs category')
plt.show()

# %% [markdown]
#  - By this box plot we can tell that usually apps related to ***GAME*** are likely to have more Size
